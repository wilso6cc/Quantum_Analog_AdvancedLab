# %%
import matplotlib.pyplot as plt
from config import spectra_style, plot_style
from data import linear, linear_filenames, onedimensional, onedimensional_filenames
import numpy as np
import os
from scipy.special import eval_legendre
from config import modeling_hydrogen_atom_folder, modeling_molecule_folder
from config import plot_style, spectra_style

# %%
from data import molecule, atom

for type in ['5mm', '10mm', '15mm', '20mm']:
    plt.style.use(spectra_style)
    plt.figure()

    plt.plot(molecule[type]['frequency'], molecule[type]['amplitude'], color='black')

    plt.xlabel("Frequency [kHz]")
    plt.ylabel("Amplitude [a.u.]")

    # save_path = {f"./Plots/full_spectra/molecule/spectra/{type}_spectra.png"}
    plt.xlim(0, 3001)
    plt.tight_layout()
    # plt.savefig(save_path)
    plt.show()
